# %%
#Get New Code
#IMplement
#Get more understanding on Drop Connect
#Get more understanding on L1 regularization
#Adam Optimizer

# %%
import tensorflow as tf
import numpy as np

from tensorflow.examples.tutorials.mnist import input_data

#
# ==================================================================
#

def weight_variable(shape):
    initial = tf.truncated_normal( shape, stddev=0.1 )
    return tf.Variable( initial )

def bias_variable(shape):
    initial = tf.constant( 0.1, shape=shape )
    return tf.Variable(initial)

#
# ==================================================================
#

p = [ 0.1, 0.25, 0.5, 0.75, 1.0 ] #  <--- Changed Here !!!
pIndex = 2

# %%
# Declare computation graph

y_ = tf.placeholder( tf.float32, shape=[None, 10], name="y_" )
x = tf.placeholder( tf.float32, [None, 784], name="x" )

W1 = weight_variable([784, 500])
b1 = bias_variable([500])
h1 = tf.matmul( x, W1 ) + b1

U1 = (np.random.rand(*h1.shape) < p[pIndex]) / p[pIndex] #  <--- Changed Here !!! Change to inverted dropout then you can leave unchanged during testing
h1 *= U1                                                 #  <--- Changed Here !!! 

W2 = weight_variable([500, 500])
b2 = bias_variable([500])
h2 = tf.matmul( h1, W2 ) + b2

U2 = (np.random.rand(*h2.shape) < p[pIndex]) / p[pIndex] #  <--- Changed Here !!!
h2 *= U2                                                 #  <--- Changed Here !!! 

W3 = weight_variable([500, 1000])
b3 = bias_variable([1000])
h3 = tf.matmul( h2, W3 ) + b3

U3 = (np.random.rand(*h3.shape) < p[pIndex]) / p[pIndex] #  <--- Changed Here !!!
h3 *= U3                                                 #  <--- Changed Here !!! 

W4 = weight_variable([1000, 10])
b4 = bias_variable([10])
y_hat = tf.nn.softmax(tf.matmul(h3, W4) + b4)

cross_entropy = tf.reduce_mean(-tf.reduce_sum(y_ * tf.log(y_hat), reduction_indices=[1]))
xent_summary = tf.scalar_summary( 'xent', cross_entropy )

correct_prediction = tf.equal(tf.argmax(y_hat,1), tf.argmax(y_,1)) #  <--- Changed Here ???
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
acc_summary = tf.scalar_summary( 'accuracy', accuracy )

train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)

# %%
#
# ==================================================================
#

sess = tf.Session()
sess.run( tf.initialize_all_variables() )

#
# ==================================================================
#

# NOTE: we're using a single, fixed batch of the first 1000 images
mnist = input_data.read_data_sets( "MNIST_data/", one_hot=True )

images = mnist.train.images[ 0:1000, : ]
labels = mnist.train.labels[ 0:1000, : ]
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
for i in range( 150 ):
    _, acc = sess.run( [ train_step, accuracy ], feed_dict={ x: images, y_: labels } )
    print( "step %d, training accuracy %g" % (i, acc) )
# Out:
# step 0, training accuracy 0.094
# step 1, training accuracy 0.109
# step 2, training accuracy 0.139
# step 3, training accuracy 0.181
# step 4, training accuracy 0.233
# step 5, training accuracy 0.314
# step 6, training accuracy 0.374
# step 7, training accuracy 0.432
# step 8, training accuracy 0.505
# step 9, training accuracy 0.564
# step 10, training accuracy 0.598
# step 11, training accuracy 0.632
# step 12, training accuracy 0.657
# step 13, training accuracy 0.686
# step 14, training accuracy 0.713
# step 15, training accuracy 0.725
# step 16, training accuracy 0.742
# step 17, training accuracy 0.75
# step 18, training accuracy 0.766
# step 19, training accuracy 0.778
# step 20, training accuracy 0.795
# step 21, training accuracy 0.803
# step 22, training accuracy 0.812
# step 23, training accuracy 0.823
# step 24, training accuracy 0.834
# step 25, training accuracy 0.838
# step 26, training accuracy 0.845
# step 27, training accuracy 0.853
# step 28, training accuracy 0.858
# step 29, training accuracy 0.865
# step 30, training accuracy 0.866
# step 31, training accuracy 0.874
# step 32, training accuracy 0.886
# step 33, training accuracy 0.895
# step 34, training accuracy 0.899
# step 35, training accuracy 0.9
# step 36, training accuracy 0.904
# step 37, training accuracy 0.911
# step 38, training accuracy 0.915
# step 39, training accuracy 0.916
# step 40, training accuracy 0.918
# step 41, training accuracy 0.919
# step 42, training accuracy 0.923
# step 43, training accuracy 0.93
# step 44, training accuracy 0.932
# step 45, training accuracy 0.938
# step 46, training accuracy 0.94
# step 47, training accuracy 0.943
# step 48, training accuracy 0.944
# step 49, training accuracy 0.95
# step 50, training accuracy 0.95
# step 51, training accuracy 0.95
# step 52, training accuracy 0.951
# step 53, training accuracy 0.955
# step 54, training accuracy 0.958
# step 55, training accuracy 0.96
# step 56, training accuracy 0.961
# step 57, training accuracy 0.963
# step 58, training accuracy 0.964
# step 59, training accuracy 0.97
# step 60, training accuracy 0.972
# step 61, training accuracy 0.972
# step 62, training accuracy 0.975
# step 63, training accuracy 0.976
# step 64, training accuracy 0.977
# step 65, training accuracy 0.978
# step 66, training accuracy 0.978
# step 67, training accuracy 0.979
# step 68, training accuracy 0.979
# step 69, training accuracy 0.979
# step 70, training accuracy 0.98
# step 71, training accuracy 0.981
# step 72, training accuracy 0.983
# step 73, training accuracy 0.985
# step 74, training accuracy 0.985
# step 75, training accuracy 0.986
# step 76, training accuracy 0.986
# step 77, training accuracy 0.989
# step 78, training accuracy 0.989
# step 79, training accuracy 0.99
# step 80, training accuracy 0.99
# step 81, training accuracy 0.99
# step 82, training accuracy 0.99
# step 83, training accuracy 0.99
# step 84, training accuracy 0.991
# step 85, training accuracy 0.992
# step 86, training accuracy 0.992
# step 87, training accuracy 0.992
# step 88, training accuracy 0.992
# step 89, training accuracy 0.992
# step 90, training accuracy 0.992
# step 91, training accuracy 0.992
# step 92, training accuracy 0.992
# step 93, training accuracy 0.992
# step 94, training accuracy 0.992
# step 95, training accuracy 0.992
# step 96, training accuracy 0.992
# step 97, training accuracy 0.992
# step 98, training accuracy 0.992
# step 99, training accuracy 0.992
# step 100, training accuracy 0.992
# step 101, training accuracy 0.993
# step 102, training accuracy 0.993
# step 103, training accuracy 0.993
# step 104, training accuracy 0.993
# step 105, training accuracy 0.994
# step 106, training accuracy 0.994
# step 107, training accuracy 0.994
# step 108, training accuracy 0.994
# step 109, training accuracy 0.994
# step 110, training accuracy 0.995
# step 111, training accuracy 0.995
# step 112, training accuracy 0.995
# step 113, training accuracy 0.996
# step 114, training accuracy 0.996
# step 115, training accuracy 0.996
# step 116, training accuracy 0.996
# step 117, training accuracy 0.996
# step 118, training accuracy 0.996
# step 119, training accuracy 0.996
# step 120, training accuracy 0.996
# step 121, training accuracy 0.996
# step 122, training accuracy 0.997
# step 123, training accuracy 0.997
# step 124, training accuracy 0.998
# step 125, training accuracy 0.998
# step 126, training accuracy 0.998
# step 127, training accuracy 0.998
# step 128, training accuracy 0.999
# step 129, training accuracy 0.999
# step 130, training accuracy 0.999
# step 131, training accuracy 0.999
# step 132, training accuracy 0.999
# step 133, training accuracy 0.999
# step 134, training accuracy 1
# step 135, training accuracy 1
# step 136, training accuracy 1
# step 137, training accuracy 1
# step 138, training accuracy 1
# step 139, training accuracy 1
# step 140, training accuracy 1
# step 141, training accuracy 1
# step 142, training accuracy 1
# step 143, training accuracy 1
# step 144, training accuracy 1
# step 145, training accuracy 1
# step 146, training accuracy 1
# step 147, training accuracy 1
# step 148, training accuracy 1
# step 149, training accuracy 1

# %%
#      if i%10==0:
#      tmp = sess.run( accuracy, feed_dict={ x: mnist.test.images, y_: mnist.test.labels } )
#      print( "          test accuracy %g" % tmp )

#
# ==================================================================
#

final_acc = sess.run( accuracy, feed_dict={ x: mnist.test.images, y_: mnist.test.labels } )
print( "test accuracy %g" % final_acc )
# Out:
# test accuracy 0.8017
